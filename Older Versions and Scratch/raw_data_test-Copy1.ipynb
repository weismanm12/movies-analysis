# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
file_path = r"C:\Users\weism\OneDrive\life stuff\Personal Projects\imdb database analysis\title.basics.tsv"

# %%
titles_df = pd.read_csv(file_path, delimiter="\t", nrows=1000)

# %%
titles_df
# Out:
#         tconst titleType                                       primaryTitle  \
# 0    tt0000001     short                                         Carmencita
# 1    tt0000002     short                             Le clown et ses chiens
# 2    tt0000003     short                                     Pauvre Pierrot
# 3    tt0000004     short                                        Un bon bock
# 4    tt0000005     short                                   Blacksmith Scene
# ..         ...       ...                                                ...
# 995  tt0001007     movie                       La primera y segunda casetas
# 996  tt0001008     short                          The Prince and the Pauper
# 997  tt0001009     short             Princess Nicotine; or, the Smoke Fairy
# 998  tt0001010     movie  Protección de un convoy de víveres en el puent...
# 999  tt0001011     short                                   The Prussian Spy
#
# ...

# %%
titles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          1000 non-null   object
#  1   titleType       1000 non-null   object
#  2   primaryTitle    1000 non-null   object
#  3   originalTitle   1000 non-null   object
#  4   isAdult         1000 non-null   int64
#  5   startYear       1000 non-null   int64
#  6   endYear         1000 non-null   object
#  7   runtimeMinutes  1000 non-null   object
#  8   genres          1000 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 70.4+ KB

# %%
titles_df.isnull().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %%
titles_df = titles_df.replace(r'^\\N$', pd.NA, regex=True)

# %%
titles_df[titles_df.isnull().any(axis=1)]
# Out:
#         tconst titleType                                       primaryTitle  \
# 0    tt0000001     short                                         Carmencita
# 1    tt0000002     short                             Le clown et ses chiens
# 2    tt0000003     short                                     Pauvre Pierrot
# 3    tt0000004     short                                        Un bon bock
# 4    tt0000005     short                                   Blacksmith Scene
# ..         ...       ...                                                ...
# 995  tt0001007     movie                       La primera y segunda casetas
# 996  tt0001008     short                          The Prince and the Pauper
# 997  tt0001009     short             Princess Nicotine; or, the Smoke Fairy
# 998  tt0001010     movie  Protección de un convoy de víveres en el puent...
# 999  tt0001011     short                                   The Prussian Spy
#
# ...

# %%
principals_path = r"C:\Users\weism\OneDrive\life stuff\Personal Projects\imdb database analysis\title.principals.tsv"

# %%
principals_df = pd.read_csv(principals_path, delimiter="\t", nrows=1000)

# %%
principals_df.isnull().sum()
# Out:
# tconst        0
# ordering      0
# nconst        0
# category      0
# job           0
# characters    0
# dtype: int64

# %%
principals_df = principals_df.replace(r'^\\N$', pd.NA, regex=True)

# %%
principals_df.isnull().sum()
# Out:
# tconst          0
# ordering        0
# nconst          0
# category        0
# job           895
# characters    759
# dtype: int64

# %%
principals_df
# Out:
#         tconst  ordering     nconst             category  \
# 0    tt0000001         1  nm1588970                 self
# 1    tt0000001         2  nm0005690             director
# 2    tt0000001         3  nm0374658      cinematographer
# 3    tt0000002         1  nm0721526             director
# 4    tt0000002         2  nm1335271             composer
# ..         ...       ...        ...                  ...
# 995  tt0000555         4  nm0630737               writer
# 996  tt0000555         5  nm0333175      cinematographer
# 997  tt0000555         6  nm0470250  production_designer
# 998  tt0000556         1  nm0422149              actress
# 999  tt0000556         2  nm0488932                actor
#
#                          job      characters
# 0                       <NA>        ["Self"]
# 1                       <NA>            <NA>
# 2    director of photography            <NA>
# 3                       <NA>            <NA>
# 4                       <NA>            <NA>
# ...

# %%
principals_df["characters"] = principals_df["characters"].replace("[\[\]]", "", regex=True)

# %%
principals_df["characters"].astype("str").isnull().sum()
# Out:
# 0

# %%
principals_df["characters"].isnull().sum()
# Out:
# 759

# %%
# apply() method iterates over all values in "genres" series
# # lambda function uses conditional logic to check if x is a list. If not, "False" is returned. If yes, any() function is applied
# any() is a generator expression that iterates over an iterable (in this case the "values" in x list) and returns True if any value returns true within the expression
# This is an example of using conditional expressions to assign values
drop_cols = titles_ratings_df.loc[titles_ratings_df["genres"].apply(lambda x: any(value == "Adult" for value in x) if isinstance(x, list) else False)]

# %%
from imdb_etl.ipynb import titles_ratings_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from imdb_etl.ipynb import titles_ratings_df
#
# ModuleNotFoundError: No module named 'imdb_etl'

# %%
titles_ratings_df.drop(drop_cols.index, inplace=True)
